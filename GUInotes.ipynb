# %%
import tkinter

class MyGUI:
    def __init__(self):
        self.main_window = tkinter.Tk()
        
        self.label1 = tkinter.Label(self.main_window,
                                   text='Hello World!',
                                   borderwidth=1,
                                   relief=sunken)
        
        self.label2 = tkinter.Label(self.main_window,
                                   text='My first GUI',
                                   borderwidth=1,
                                   relief=sunken)
        
        self.label1.pack(side='left')
        self.label2.pack(side='left')
        
        tkinter.mainloop()
        
        
        
        
if __name__ =='__main__':
    my_gui = myGUI()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 23
#      17         tkinter.mainloop()
#      22 if __name__ =='__main__':
# ---> 23     my_gui = myGUI()
#
# NameError: name 'myGUI' is not defined

# %%
# imports tkinter module 
import tkinter

# class that creates a GUI which calculates 
# the average of 3 test scores 
class TestAVG():
    def __init__(self):
        # creates main window
        self.main_window = tkinter.Tk()
        
        # creates the 5 frames of the GUI
        self.test1_frame = tkinter.Frame(self.main_window)
        self.test2_frame = tkinter.Frame(self.main_window)
        self.test3_frame = tkinter.Frame(self.main_window)
        self.avg_frame = tkinter.Frame(self.main_window)
        self.button_frame = tkinter.Frame(self.main_window)
        
        
        
        
        # creates test 1 label and entry box then packs them
        self.test1_label = tkinter.Label(self.test1_frame,
                                         text='Enter the score for Test 1:')
        self.test1_entry = tkinter.Entry(self.test1_frame,
                                         width=10)
        
        self.test1_label.pack(side='left')
        self.test1_entry.pack(side='left')
        
        
        
        
        # creates test 2 label and entry box then packs them
        self.test2_label = tkinter.Label(self.test2_frame,
                                         text='Enter the score for Test 2:')
        self.test2_entry = tkinter.Entry(self.test2_frame,
                                         width=10)
        
        self.test2_label.pack(side='left')
        self.test2_entry.pack(side='left')
        
        
        
        
        # creates test 3 label and entry box then packs them 
        self.test3_label = tkinter.Label(self.test3_frame,
                                         text='Enter the score for Test 3:')
        self.test3_entry = tkinter.Entry(self.test3_frame,
                                         width=10)
        
        self.test3_label.pack(side='left')
        self.test3_entry.pack(side='left')
        
        
        
        
        
        # creates result label 
        self.result_label = tkinter.Label(self.avg_frame,
                                          text='Average:')
        
        # uses StringVar to hold value of user entered 
        # value 
        self.avg = tkinter.StringVar()
        
        # label container that displays value of StringVar
        self.avg_label = tkinter.Label(self.avg_frame, 
                                       textvariable=self.avg)
        
        
        # packs result and avg labels 
        self.result_label.pack(side='left')
        self.avg_label.pack(side='left')
        
        
        
        # creates the calculate avg button that calls the 
        # calc_avg function to perform the numeric calculations
        self.calc_button = tkinter.Button(self.button_frame,
                                          text='Average',
                                          command=self.calc_avg())
        
        # creates a quit button that exits the program
        self.quit_button = tkinter.Button(self.button_frame,
                                          text='Quit',
                                          command=self.main_window.destroy)
        
        # packs the buttons in left aligned order
        self.calc_button.pack(side='left')
        self.quit_button.pack(side='left')
        
        
        # packs all 5 frames 
        self.test1_frame.pack()
        self.test2_frame.pack()
        self.test3_frame.pack()
        self.avg_frame.pack()
        self.button_frame.pack()
        
        # starts the main loop of the program
        tkinter.mainloop()
        
        
        # function that calculates the average of 
        # three test scores 
        def calc_avg(self):
            self.test1 = float(self.test1_entry.get())
            self.test2 = float(self.test2_entry.get())
            self.test3 = float(self.test3_entry.get())
            
            
            self.average = (self.test1_entry + self.test2_entry + self.test3_entry) / 3
            
            # uses the set methods to set the average of 
            # the 3 grades 
            self.avg.set(self.average)





if __name__ == '__main__':
    test_avg = TestAVG()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 107
#     100             self.avg.set(self.average)
#     106 if __name__ == '__main__':
# --> 107     test_avg = TestAVG()
#
# Cell In[1], line 72, in TestAVG.__init__(self)
#      64 self.result_label.pack(side='left')
#      65 self.avg_label.pack(side='left')
#      70 self.calc_button = tkinter.Button(self.button_frame,
#      71                                   text='Average',
# ---> 72                                   command=self.calc_avg)
#      74 self.quit_button = tkinter.Button(self.button_frame,
#      75                                   text='Quit',
#      76                                   command=self.main_window.destroy)
#      78 self.calc_button.pack(side='left')
#
# AttributeError: 'TestAVG' object has no attribute 'calc_avg'
