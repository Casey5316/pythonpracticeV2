# %% [markdown]
# ## What will the following code display?

# %%
numbers = [1, 2, 3, 4, 5]
numbers[2] = 99
print(numbers)
# Out:
# [1, 2, 99, 4, 5]

# %%
numbers = list(range(3))
print(numbers)
# Out:
# [0, 1, 2]

# %%
import random

names = ['Servy', 'Kevin', 'Roman', 'Tim', 'Casey', 'Jesse']

winner = random.choices(names, k=2)

print(f'Congratulations {winner}! You won an all expenses free\n'
     + 'trip to Patty King\'s house!')
# Out:
# Congratulations ['Servy', 'Roman']! You won an all expenses free
# trip to Patty King's house!

# %%
# main program checks if i just met you and
# if this is crazy. If True, here's my number
# so call me maybe 
def main():
    i_just_met_you = input('Did I just meet you? ')
    this_is_crazy = input('Is this crazy? ')
    
    
    while i_just_met_you == 'y' and this_is_crazy == 'y':
        print(f'Here\'s my number, so call me maybe.')
        i_just_met_you = input('Did I just meet you? ')
        this_is_crazy = input('Is this crazy? ')
        
        
        
if __name__ == '__main__':
    main()
# Out:
# Did I just meet you? y
# Is this crazy? y
# Here's my number, so call me maybe.
# Did I just meet you? n
# Is this crazy? n

# %% [markdown]
# ## Series of nested loops that displays the contents of a two dimensional list

# %%
def main():
    ROWS = 4
    COLS = 2
    
    
    numbers = [[1, 2], [10, 20], [100, 200], [1000, 2000]]
    
    for row in numbers:
        for element in row:
            print(element)




if __name__ == '__main__':
    main()
# Out:
# 1
# 2
# 10
# 20
# 100
# 200
# 1000
# 2000

# %% [markdown]
# ## Import matplotlib.pyplot example to plot coordinates from lists. Updated to show title, axis labels, and grid.

# %%
import matplotlib.pyplot as plt

x_coord = [0, 2, 4, 6, 8]

y_coord = [0, 3, 7, 6, 11]

plt.title('My First Graph')

plt.xlabel('Time')

plt.ylabel('More stuff')

plt.grid(True)

plt.plot(x_coord, y_coord)

plt.show()

# %% [markdown]
# ## Setting the limits of your axes

# %%
import matplotlib.pyplot as plt

x_coord = [44, 77, 109, 115, 147]
y_coord = [67, 22, 59, 89, 107]

plt.title('My Second Graph')

plt.xlabel('Time')

plt.ylabel('More stuff')

plt.grid(True)

# sets x and y limits that display
# on graph
plt.xlim(xmax = 147, xmin = 25)

plt.ylim(ymax = 125, ymin = 0)

plt.plot(x_coord, y_coord)

plt.show()

# %% [markdown]
# ## Added xticks for the years on the x axis. Also added markers for each piece of data.

# %%
x_coord = [0, 50, 75, 100]

y_coord = [0, 55, 46, 88]

plt.grid(True)

plt.ylim(ymin = 25, ymax = 100)

plt.xlim(xmin = 25, xmax = 100)

plt.title('Sales chart')

plt.xlabel('Time')

plt.ylabel('Sales in $')

plt.xticks([0, 25, 50, 75, 100], ['2017', '2018', '2019', '2020', '2021'])

plt.yticks([])

plt.plot(x_coord, y_coord, marker = 'o')

plt.show()

# %% [markdown]
# ## How to create a bar graph using matplotlib.pyplot. Customized bar width.

# %%
import matplotlib.pyplot as plt
BAR_WIDTH = 5


left_edges = [0, 10, 20, 30, 40]

heights = [77, 120, 177, 210, 260]

plt.bar(left_edges, heights, BAR_WIDTH, color = ('r', 'g', 'b', 'c', 'k'))

plt.title('My First Bar Graph')

plt.xlabel('Years')
plt.ylabel('Sales')

plt.ylim(ymax = 250, ymin = 0)

plt.yticks([0, 50, 100, 150, 200],
           ['$0', '$10K', '$20K', '$30K', '$40K'])





plt.show()

# %% [markdown]
# ## How to create a pie chart

# %%
import matplotlib.pyplot as plt

values = [10, 30, 40, 20]

plt.pie(values, labels = slice_labels, colors = ('c', 'k', 'g', 'b'))

slice_labels = ['Gas', 'Food', 'Entertainment', 'Bills']

plt.show()
